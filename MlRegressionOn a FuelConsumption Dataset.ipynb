# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/Users/apple/Documents/GeetaChoudhary/datascience4/machine_csv/FuelConsumption.csv")

# %%
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
df.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
###Select those feature in dataset that are used in prediction
df = df[["ENGINESIZE","CO2EMISSIONS"]]

# %%
df.head()
# Out:
#    ENGINESIZE  CO2EMISSIONS
# 0         2.0           196
# 1         2.4           221
# 2         1.5           136
# 3         3.5           255
# 4         3.5           244

# %%
df.tail()
# Out:
#       ENGINESIZE  CO2EMISSIONS
# 1062         3.0           271
# 1063         3.2           264
# 1064         3.0           271
# 1065         3.2           260
# 1066         3.2           294

# %%
###Scatter plot
plt.scatter(df['ENGINESIZE'],df['CO2EMISSIONS'],color = 'gray')
plt.xlabel('ENGINESIZE')
plt.ylabel('CO2EMISSIONS')
plt.title('ENGINESIZE VS CO2EMISSIONS')
plt.show()

# %%
###Split the data into tranning and testing
##80% train and 20%test data
num = int(len(df)*0.8)
train = df[:num]
test = df[num:]
print('Data is',len(df))
print('Train is',len(train))
print('Test is',len(test))
# Out:
# Data is 1067
# Train is 853
# Test is 214
